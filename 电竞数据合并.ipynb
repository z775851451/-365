# %%
import os 
import pandas as pd

# %%
dir = os.listdir('源/电竞店铺流量数据/新建文件夹 (2)')

# %%
for i in dir:
    df = pd.read_excel('源/电竞店铺流量数据/新建文件夹 (2)/'+i+'')
    df.to_excel('源/电竞店铺流量数据/new/'+i+'.xlsx')
    # print('源/电竞业务数据/'+i+'/'+i+'.xls')

# %%
dir[0]
# Out:
# '流量概况_核心指标_2021年11月01日.xls'

# %%
import matplotlib.pyplot

# %%
dataset = pd.read_excel(r'D:\工作目录\xx\xx\报表\sql导入\源\电竞店铺流量数据\test.xlsx')

# %%
matplotlib.pyplot.plot(dataset.全部渠道,
         dataset.访客数,
         linestyle = '-', # 折线类型
         linewidth = 2, # 折线宽度
         color = 'steelblue', # 折线颜色
         marker = 'o', # 点的形状
         markersize = 6, # 点的大小
         markeredgecolor='black', # 点的边框色
         markerfacecolor='brown'
         )

# %%
a = '订单编号,店铺,订单来源,仓库,子单原始单号,订单状态,订单类型,货到付款,订单退款状态,交易时间,付款时间,货品名称,规格名称,平台货品名称,平台规格名称,下单数量,标价,货品总优惠,成交价,分摊后价格,折扣,实发数量,分摊后总价,退款前支付金额,分摊邮费,单品支付金额'

# %%
a
# Out:
# '订单编号,店铺,订单来源,仓库,子单原始单号,订单状态,订单类型,货到付款,订单退款状态,交易时间,付款时间,货品名称,规格名称,平台货品名称,平台规格名称,下单数量,标价,货品总优惠,成交价,分摊后价格,折扣,实发数量,分摊后总价,退款前支付金额,分摊邮费,单品支付金额'

# %%
a.split(',')
# Out:
# ['订单编号',
#  '店铺',
#  '订单来源',
#  '仓库',
#  '子单原始单号',
#  '订单状态',
#  '订单类型',
#  '货到付款',
#  '订单退款状态',
#  '交易时间',
#  '付款时间',
#  '货品名称',
#  '规格名称',
#  '平台货品名称',
#  '平台规格名称',
#  '下单数量',
#  '标价',
#  '货品总优惠',
#  '成交价',
#  '分摊后价格',
#  '折扣',
#  '实发数量',
#  '分摊后总价',
#  '退款前支付金额',
#  '分摊邮费',
#  '单品支付金额']
